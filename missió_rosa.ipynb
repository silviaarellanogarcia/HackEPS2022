# %% [markdown]
# <a href="https://colab.research.google.com/github/silviaarellanogarcia/HackEPS2022/blob/main/missi%C3%B3_rosa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌸 MISSIÓ ROSA 🌸

# %% [markdown]
# (En construcció)

# %% [markdown]
# ## Objectius
#
# Ostres! Les nostres càmares estàn fallant molt últimament i no rebem bé les imatges. Podriem reparar les imatges i tornar a tenir-les lo més semblant al que esperem? Per provar el vostre model generatiu, us hem deixat el dataset A3 , no obstant això, pel seu entrenament podeu utilitzar els altres datasets.
#
# ![image.png](data:image/png;base64,...)
# No saps quins models podrien anar bé? Vine a preguntar-nos!

# %%
# Llibreries necessàries
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#!unzip "gdrive/MyDrive/HackEPS2022/data/A3.zip" -d "gdrive/MyDrive/HackEPS2022/data/rosa"

# %%
import matplotlib.pyplot as plt


img_mal = plt.imread(f'gdrive/MyDrive/HackEPS2022/data/rosa/A3/to/c1r1e0n2-28.png')
plt.imshow(img_mal)
plt.title(f'c1r1e0n2-28.png')
plt.show()

# %%
import cv2
import os

# %%
img_mal = cv2.imread('gdrive/MyDrive/HackEPS2022/data/rosa/A3/to/c1r1e0n2-28.png')

color = ('b','g','r')

for i, c in enumerate(color):
    hist = cv2.calcHist([img_mal], [i], None, [256], [0, 256])
    plt.plot(hist, color = c)
    plt.xlim([0,256])

plt.show()

cv2.destroyAllWindows()

# %%
img = cv2.imread('gdrive/MyDrive/HackEPS2022/data/rosa/A3/from/c1r1e2n6.tif')

color = ('b','g','r')

for i, c in enumerate(color):
    hist = cv2.calcHist([img], [i], None, [256], [0, 256])
    plt.plot(hist, color = c)
    plt.xlim([0,256])

plt.show()

cv2.destroyAllWindows()

# %%
plt.imshow(img)

# %%
img_mal = cv2.imread('gdrive/MyDrive/HackEPS2022/data/rosa/A3/to/c1r1e0n2-28.png')

color = ('b','g','r')

for i, c in enumerate(color):
    hist = cv2.calcHist([img_mal], [i], None, [256], [0, 256])
    plt.plot(hist, color = c)
    plt.xlim([0,256])

plt.show()

cv2.destroyAllWindows()

# %% [markdown]
# Hem observat que l'histograma del color gris del teixit es com una campana entre els valors 120 i 180 aprox. La idea seria eliminar els valors que no formen part d'aquest rang als 3 canals RGB.
#
# La nostra idea seria crear una mascara on els valors RGB entre 120 i 150 tinguessin valor 1 i el resto de valors siguin 0. Llavors, al multiplicar la mascara amb la senyal original es reduirien les components de color que més s'allunyen de les del gris. Per tant, encara que no s'eliminés per complet, aconseguiriem que el color sigués molt més similar.
